# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\navan\OneDrive\Desktop\PROJECT\project 2\all_colege_list.csv")

# %%
df
# Out:
#                                  College Name                       Location  \
# 0                           Andhra University  Visakhapatnam, Andhra Pradesh
# 1                               KL University         Guntur, Andhra Pradesh
# 2           Sri Venkateswara University (SVU)       Tirupati, Andhra Pradesh
# 3                  Aditya Engineering College  East Godavari, Andhra Pradesh
# 4                               Vignan Online         Guntur, Andhra Pradesh
# ..                                        ...                            ...
# 455                The Global Open University              Dimapur, Nagaland
# 456                             Alder College               Kohima, Nagaland
# 457  Anderson Theological College, Zunhebotto            Zunheboto, Nagaland
# 458       Discipleship Bible College, Dimapur              Dimapur, Nagaland
# 459                          Immanuel College              Dimapur, Nagaland
#
# ...

# %%
df.head()
# Out:
#                         College Name                       Location     Type  \
# 0                  Andhra University  Visakhapatnam, Andhra Pradesh   Public
# 1                      KL University         Guntur, Andhra Pradesh  Private
# 2  Sri Venkateswara University (SVU)       Tirupati, Andhra Pradesh   Public
# 3         Aditya Engineering College  East Godavari, Andhra Pradesh  Private
# 4                      Vignan Online         Guntur, Andhra Pradesh      NaN
#
#    Rating  Courses offered Fee Start Range Fee End Range
# 0     3.6               34            16 K       14.44 L
# 1     3.5               23          1.40 L       15.60 L
# 2     3.5               18             8 K        2.71 L
# 3     3.7                5            54 K        2.01 L
# 4     NaN                3          1.10 L        1.35 L

# %%
df.tail()
# Out:
#                                  College Name             Location     Type  \
# 455                The Global Open University    Dimapur, Nagaland   Public
# 456                             Alder College     Kohima, Nagaland   Public
# 457  Anderson Theological College, Zunhebotto  Zunheboto, Nagaland  Private
# 458       Discipleship Bible College, Dimapur    Dimapur, Nagaland  Private
# 459                          Immanuel College    Dimapur, Nagaland  Private
#
#      Rating  Courses offered Fee Start Range Fee End Range
# 455     NaN               21            45 K           5 L
# 456     NaN                1            28 K          75 K
# 457     NaN                2            10 K          25 K
# 458     NaN                1            30 K        1.25 L
# 459     NaN                2             3 K          88 K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   College Name     460 non-null    object
#  1   Location         460 non-null    object
#  2   Type             438 non-null    object
#  3   Rating           328 non-null    float64
#  4   Courses offered  460 non-null    int64
#  5   Fee Start Range  460 non-null    object
#  6   Fee End Range    404 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 25.3+ KB

# %%
df.isna()
# Out:
#      College Name  Location   Type  Rating  Courses offered  Fee Start Range  \
# 0           False     False  False   False            False            False
# 1           False     False  False   False            False            False
# 2           False     False  False   False            False            False
# 3           False     False  False   False            False            False
# 4           False     False   True    True            False            False
# ..            ...       ...    ...     ...              ...              ...
# 455         False     False  False    True            False            False
# 456         False     False  False    True            False            False
# 457         False     False  False    True            False            False
# 458         False     False  False    True            False            False
# 459         False     False  False    True            False            False
#
#      Fee End Range
# 0            False
# ...

# %%
df.isna().sum()
# Out:
# College Name         0
# Location             0
# Type                22
# Rating             132
# Courses offered      0
# Fee Start Range      0
# Fee End Range       56
# dtype: int64

# %%
df_cleaned = df.fillna(0)
df_cleaned
# Out:
#                                  College Name                       Location  \
# 0                           Andhra University  Visakhapatnam, Andhra Pradesh
# 1                               KL University         Guntur, Andhra Pradesh
# 2           Sri Venkateswara University (SVU)       Tirupati, Andhra Pradesh
# 3                  Aditya Engineering College  East Godavari, Andhra Pradesh
# 4                               Vignan Online         Guntur, Andhra Pradesh
# ..                                        ...                            ...
# 455                The Global Open University              Dimapur, Nagaland
# 456                             Alder College               Kohima, Nagaland
# 457  Anderson Theological College, Zunhebotto            Zunheboto, Nagaland
# 458       Discipleship Bible College, Dimapur              Dimapur, Nagaland
# 459                          Immanuel College              Dimapur, Nagaland
#
# ...

# %%
df_cleaned.isna().sum()
# Out:
# College Name       0
# Location           0
# Type               0
# Rating             0
# Courses offered    0
# Fee Start Range    0
# Fee End Range      0
# dtype: int64

# %%
df_cleaned.dtypes
# Out:
# College Name        object
# Location            object
# Type                object
# Rating             float64
# Courses offered      int64
# Fee Start Range     object
# Fee End Range       object
# dtype: object

# %%
df_cleaned['Rating'] = pd.to_numeric(df_cleaned['Rating'], errors='coerce')
# Step 2: Convert 'Fee Start Range' and 'Fee End Range' to float
# Remove characters like 'K' and 'L' and convert to numeric values
df_cleaned['Fee Start Range'] = df_cleaned['Fee Start Range'].replace({' K': 'e3', ' L': 'e5'}, regex=True)
df_cleaned['Fee Start Range'] = pd.to_numeric(df_cleaned['Fee Start Range'], errors='coerce')

df_cleaned['Fee End Range'] = df_cleaned['Fee End Range'].replace({' K': 'e3', ' L': 'e5'}, regex=True)
df_cleaned['Fee End Range'] = pd.to_numeric(df_cleaned['Fee End Range'], errors='coerce')

# %%
df_cleaned
# Out:
#                                  College Name                       Location  \
# 0                           Andhra University  Visakhapatnam, Andhra Pradesh
# 1                               KL University         Guntur, Andhra Pradesh
# 2           Sri Venkateswara University (SVU)       Tirupati, Andhra Pradesh
# 3                  Aditya Engineering College  East Godavari, Andhra Pradesh
# 4                               Vignan Online         Guntur, Andhra Pradesh
# ..                                        ...                            ...
# 455                The Global Open University              Dimapur, Nagaland
# 456                             Alder College               Kohima, Nagaland
# 457  Anderson Theological College, Zunhebotto            Zunheboto, Nagaland
# 458       Discipleship Bible College, Dimapur              Dimapur, Nagaland
# 459                          Immanuel College              Dimapur, Nagaland
#
# ...

# %%
df_cleaned.to_csv('cleaned_colleges.csv', index=False)

# %%
df_cleaned = df.copy()

# Split the 'Location' column into 'City' and 'State' columns correctly
df_cleaned[['City', 'State']] = df_cleaned['Location'].str.split(',', n=1, expand=True)
# Drop the 'Location' column if it's no longer needed
df_cleaned.drop(columns=['Location'], inplace=True)
# Display the updated DataFrame
print(df_cleaned)
# Out:
#                                  College Name     Type  Rating  \
# 0                           Andhra University   Public     3.6
# 1                               KL University  Private     3.5
# 2           Sri Venkateswara University (SVU)   Public     3.5
# 3                  Aditya Engineering College  Private     3.7
# 4                               Vignan Online      NaN     NaN
# ..                                        ...      ...     ...
# 455                The Global Open University   Public     NaN
# 456                             Alder College   Public     NaN
# 457  Anderson Theological College, Zunhebotto  Private     NaN
# 458       Discipleship Bible College, Dimapur  Private     NaN
# 459                          Immanuel College  Private     NaN
#
#      Courses offered Fee Start Range Fee End Range           City  \
# 0                 34            16 K       14.44 L  Visakhapatnam
# 1                 23          1.40 L       15.60 L         Guntur
# ...

# %%
df_cleaned
# Out:
#                                  College Name     Type  Rating  \
# 0                           Andhra University   Public     3.6
# 1                               KL University  Private     3.5
# 2           Sri Venkateswara University (SVU)   Public     3.5
# 3                  Aditya Engineering College  Private     3.7
# 4                               Vignan Online      NaN     NaN
# ..                                        ...      ...     ...
# 455                The Global Open University   Public     NaN
# 456                             Alder College   Public     NaN
# 457  Anderson Theological College, Zunhebotto  Private     NaN
# 458       Discipleship Bible College, Dimapur  Private     NaN
# 459                          Immanuel College  Private     NaN
#
#      Courses offered Fee Start Range Fee End Range           City  \
# 0                 34            16 K       14.44 L  Visakhapatnam
# 1                 23          1.40 L       15.60 L         Guntur
# ...

# %%
df_cleaned1 = df_cleaned.fillna(0)
df_cleaned1
# Out:
#                                  College Name     Type  Rating  \
# 0                           Andhra University   Public     3.6
# 1                               KL University  Private     3.5
# 2           Sri Venkateswara University (SVU)   Public     3.5
# 3                  Aditya Engineering College  Private     3.7
# 4                               Vignan Online        0     0.0
# ..                                        ...      ...     ...
# 455                The Global Open University   Public     0.0
# 456                             Alder College   Public     0.0
# 457  Anderson Theological College, Zunhebotto  Private     0.0
# 458       Discipleship Bible College, Dimapur  Private     0.0
# 459                          Immanuel College  Private     0.0
#
#      Courses offered Fee Start Range Fee End Range           City  \
# 0                 34            16 K       14.44 L  Visakhapatnam
# 1                 23          1.40 L       15.60 L         Guntur
# ...
